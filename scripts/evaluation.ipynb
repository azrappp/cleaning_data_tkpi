# %%
import pandas as pd

food_candidates = pd.read_csv("../outputs/final_food_candidates_clinical.csv")

# %%
print("""MP: makanan pokok
LH: lauk hewani
LN: lauk Nabati
S: sayur
B: buah
SS: susu
M: Minyak
G: Gula""")

food_candidates.category.value_counts()
# Out:
# MP: makanan pokok
# LH: lauk hewani
# LN: lauk Nabati
# S: sayur
# B: buah
# SS: susu
# M: Minyak
# G: Gula
# category
# LH    39
# MP    31
# LN    15
# S      8
# M      6
# G      3
# B      1
# Name: count, dtype: int64

# %%
food_last = pd.read_csv("../preprocessed/final_food_candidates_dm_ht.csv")

# %%
food_last.category_code.value_counts()
# Out:
# category_code
# S     166
# B      24
# LH     24
# LN     13
# MP      5
# M       5
# SS      3
# G       1
# Name: count, dtype: int64
